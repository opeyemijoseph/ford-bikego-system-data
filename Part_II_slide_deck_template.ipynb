# %% [markdown]
# # Part II - Presentaton for Ford GoBike System Data
# ## by Opeyemi Ogundaisi

# %% [markdown]
# ## Investigation Overview
#
# ## Some Key Insights
# > There were more male in the analysis compared to female, also there was another unique gender type that was assume as other gender tyoe apart from male or female,
# > Also the regular customers types were plentier thsn the subscribers, 90.53% of the users are subscribers while the remaining 9.47% are customers,
# > More passengers started their journey from Backesto Pack than other stations,
# > More passengers ended their journey at San Fransisco Caltrain than other stations,
# > Powell Saint Bart the duration is long.

# %% [markdown]
# # Dataset Overview

# %%
#importing packages/libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# ### Cleaned dataset (Ford_Bike_Final.csv) from Exploration Template was loaded for visualization in this notebook

# %%
#Loading and previewing dataset
url = "/home/opejoseph/Documents/ALX Assignments/Ford_Bike_Final.csv"
cleaned_df = pd.read_csv(url)
cleaned_df.sample(5)
# Out:
#         Unnamed: 0          start_time_conv            end_time_conv  \
# 86244        86244  2019-02-16 12:20:14.551  2019-02-16 12:31:58.293
# 50904        50904  2019-02-21 16:07:48.616  2019-02-21 16:17:56.522
# 47540        47540  2019-02-21 20:35:09.862  2019-02-21 20:52:45.394
# 91710        91710  2019-02-15 11:05:53.567  2019-02-15 11:10:31.625
# 106181      106181  2019-02-12 17:08:35.838  2019-02-12 17:22:12.616
#
#         duration_sec                                start_station_name  \
# 86244            703  Montgomery St BART Station (Market St at 2nd St)
# 50904            607                             Sanchez St at 17th St
# 47540           1055                              Post St at Kearny St
# 91710            278  Montgomery St BART Station (Market St at 2nd St)
# 106181           816      Powell St BART Station (Market St at 5th St)
#
#         start_station_latitude  start_station_longitude  \
# 86244                37.789625              -122.400811
# 50904                37.763242              -122.430675
# 47540                37.788975              -122.403452
# 91710                37.789625              -122.400811
# 106181               37.783899              -122.408445
#
#                                     end_station_name  end_station_latitude  \
# 86244                          Townsend St at 7th St             37.771058
# 50904                    Potrero Ave and Mariposa St             37.763281
# 47540                     Rhode Island St at 17th St             37.764478
# 91710   Powell St BART Station (Market St at 4th St)             37.786375
# 106181                        Davis St at Jackson St             37.797280
#
#         end_station_longitude  bike_id   user_type  member_birth_year  \
# 86244             -122.402717     6255  Subscriber             1953.0
# 50904             -122.407377     5247  Subscriber             1988.0
# 47540             -122.402570     1844  Subscriber             1993.0
# 91710             -122.404904     6532  Subscriber             1972.0
# 106181            -122.398436     5305  Subscriber             1992.0
#
#        member_gender bike_share_for_all_trip     month start_day  hour
# 86244           Male                     Yes  February  Saturday    12
# 50904           Male                      No  February  Thursday    16
# 47540           Male                      No  February  Thursday    20
# 91710           Male                     Yes  February    Friday    11
# 106181        Female                      No  February   Tuesday    17

# %% [markdown]
# # Visualization 1
# ### In the overall analysis there are more subscribers than the 9.47% customers.

# %%
# There is ony two type of user

cleaned_df.user_type.unique()
sns.histplot(data=cleaned_df, x="user_type", hue="user_type").set(title='Distribution of UserTypes')
# Out:
# [Text(0.5, 1.0, 'Distribution of UserTypes')]

# %%
#Show user type by it's percentage

plt.figure(figsize=(10,6))
sorted_counts = cleaned_df['user_type'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,
        counterclock = False, autopct='%1.2f%%');
plt.axis('square')
plt.title('Bike User Count Comparison', fontsize=15);

# %% [markdown]
# # Visualization 2
# ### Backesto Park (Jackon St at 13th St) Station is the most popular station followed by foothill blvd at Harrington Ave.

# %%
plt.title('Most Popular Start Stations', fontsize=15)
cleaned_df.end_station_name.value_counts(ascending=True).head(10).plot.barh();

# %%
#Variable (df_longest_duration) was created to hold the sorted value of top 5 duration, it was sorted in ascending order in-order to get top 5
df_top5_longest_duration = cleaned_df.sort_values(by=['duration_sec','start_station_name'], ascending=False)
df_top5_longest_duration[['duration_sec','start_station_name']].head(5)
#making a variable to contain the top 5 columns for the columns of interest 
top_dur = df_top5_longest_duration[['duration_sec','start_station_name']].head(5)
sns.barplot(data=top_dur, x= "duration_sec", y="start_station_name").set(title='Top 5 Start Station by Duration')
# Out:
# [Text(0.5, 1.0, 'Top 5 Start Station by Duration')]

# %% [markdown]
# # Visualization 3
# ### Powell St BART Station has the highest duration followed by Page street with majority of the population as Males.

# %%
#making a variable to contain the top 5 columns for the columns of interest
top_dur = df_top5_longest_duration[['duration_sec','end_station_name','member_gender']].head(5)
sns.barplot(data=top_dur, x= "duration_sec", y="end_station_name", hue="member_gender").set(title='Duration by End Station')
# Out:
# [Text(0.5, 1.0, 'Duration by End Station')]

# %%
#plot for gender distribution
sns.histplot(data=cleaned_df, x="member_gender", hue="member_gender").set(title='Distribution of Gender')
# Out:
# [Text(0.5, 1.0, 'Distribution of Gender')]

# %%
# !jupyter nbconvert Part_II_slide_deck_template.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_slide_deck_template.ipynb to slides
# [NbConvertApp] Writing 832536 bytes to Part_II_slide_deck_template.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/Part_II_slide_deck_template.slides.html
# Use Control-C to stop this server
# 404 GET /favicon.ico (127.0.0.1) 0.80ms
